# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a429/python_lab/blob/main/merge_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q72="7.2. Write a python program to implement merge sort using lists."
print(Q72)
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])

    return result

# Example usage
lst = [5, 1, 2, 3, 7, 4]
print("Sorted Merge sort list:", merge_sort(lst))
# Out:
# 7.2. Write a python program to implement merge sort using lists.
# Sorted Merge sort list: [1, 2, 3, 4, 5, 7]
