# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a429/python_lab/blob/main/binary_to_decimal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q1="""1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark"""
print(Q1)
# Accept marks from user
m1 = int(input("Enter marks for Test 1: "))
m2 = int(input("Enter marks for Test 2: "))
m3 = int(input("Enter marks for Test 3: "))
# Find the minimum (lowest) mark to exclude
minimum = min(m1, m2, m3)
# Sum the best two marks
sum_best_two = m1 + m2 + m3 - minimum
# Calculate average of best two
average_best_two = sum_best_two / 2
print("Average of best two test marks is:", average_best_two)
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark
# Enter marks for Test 1: 8
# Enter marks for Test 2: 16
# Enter marks for Test 3: 24
# Average of best two test marks is: 20.0

# %%
Q2="""1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks"""
print(Q2)
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for ch in set(input_str):
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks
# Enter a string: access
# Not Palindrome
# 'a' appears 1 times
# 'e' appears 1 times
# 'c' appears 2 times
# 's' appears 2 times

# %%
Q3="""1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark"""
print(Q3)
number = input("Enter a number: ")
if number == number[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for i in range(10):
    count = number.count(str(i))
    if count > 0:
        print(f"{i} appears {count} times")
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark
# Enter a number: 242
# Palindrome
# 2 appears 2 times
# 4 appears 1 times

# %%
Q3="""3. Fibonacci sequence: Defined as a function F as Fn = Fn-1 + Fn-2. Write a Python program which accepts a value for N (e.g., number of terms)."""
print(Q3)

def fibonacci_sequence(N):
    if N <= 0:
        print("Error: N must be greater than 0.")
        return
    fib_list = []
    a, b = 0, 1
    for _ in range(N):
        fib_list.append(a)
        a, b = b, a + b
    print("Fibonacci sequence up to", N, "terms:", fib_list)

try:
    N = int(input("Enter the number of terms (N > 0): "))
    fibonacci_sequence(N)
except ValueError:
    print("Error: Please enter a valid integer.")
# Out:
# 3. Fibonacci sequence: Defined as a function F as Fn = Fn-1 + Fn-2. Write a Python program which accepts a value for N (e.g., number of terms).
# Enter the number of terms (N > 0): 8
# Fibonacci sequence up to 8 terms: [0, 1, 1, 2, 3, 5, 8, 13]

# %%
Q4="""Binary to Decimal & Octal to Hexadecimal Conversion: Develop a python program to convert binary to decimal, octal to hexa"""
print(Q4)
def binary_to_decimal(binary_str):
# Convert binary string to decimal integer
    return int(binary_str, 2)
def octal_to_hexadecimal(octal_str):
# Convert octal string to decimal integer, then to hexadecimal (uppercase, without '0x')
    return hex(int(octal_str, 8))[2:].upper()
# Input from user
binary = input("Enter a binary number: ")
octal = input("Enter an octal number: ")
# Function calls and output
print("Decimal value of binary:", binary_to_decimal(binary))
print("Hexadecimal value of octal:", octal_to_hexadecimal(octal))
print("---------------------------------------------1")

Note1 ="""The binary_to_decimal function uses Python's built-in int() function with base 2 to convert binary to decimal."""
Note2 ="""The octal_to_hexadecimal function converts the octal input using base 8 and then formats the result in hexadecimal us."""
Note3 ="""The output presents the conversion results without prefixes or extra formatting"""
print(Note1)
print(Note2)
print(Note3)
# Out:
# Binary to Decimal & Octal to Hexadecimal Conversion: Develop a python program to convert binary to decimal, octal to hexa
# Enter a binary number: 101
# Enter an octal number: 01
# Decimal value of binary: 5
# Hexadecimal value of octal: 1
# ---------------------------------------------1
# The binary_to_decimal function uses Python's built-in int() function with base 2 to convert binary to decimal.
# The octal_to_hexadecimal function converts the octal input using base 8 and then formats the result in hexadecimal us.
# The output presents the conversion results without prefixes or extra formatting
